# %% [markdown]
# <a href="https://colab.research.google.com/github/zh19980811/-/blob/main/%E5%B8%9D%E5%9F%8E%E6%95%B0%E5%80%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 纣王和项目对比

# %%
import pandas as pd

wu_li_range = range(900, 2500, 100)

def calculate_battle_methods(wu_li):
    # 破釜沉舟战法倍率
    pofuchenzhou = ((((wu_li - 900) + (wu_li * 0.8))/100)*2)/5
    # 纣王战法倍率
    zhouwang = (wu_li - 900 + 500)/100
    return pofuchenzhou, zhouwang

data = {
    "武力值": [],
    "破釜沉舟战法倍率": [],
    "纣王战法倍率": []
}

for wu_li in wu_li_range:
    pofuchenzhou, zhouwang = calculate_battle_methods(wu_li)
    data["武力值"].append(wu_li)
    data["破釜沉舟战法倍率"].append(pofuchenzhou)
    data["纣王战法倍率"].append(zhouwang)

df = pd.DataFrame(data)
df
# Out:
#      武力值  破釜沉舟战法倍率  纣王战法倍率
# 0    900      2.88     5.0
# 1   1000      3.60     6.0
# 2   1100      4.32     7.0
# 3   1200      5.04     8.0
# 4   1300      5.76     9.0
# 5   1400      6.48    10.0
# 6   1500      7.20    11.0
# 7   1600      7.92    12.0
# 8   1700      8.64    13.0
# 9   1800      9.36    14.0
# 10  1900     10.08    15.0
# 11  2000     10.80    16.0
# 12  2100     11.52    17.0
# 13  2200     12.24    18.0
# 14  2300     12.96    19.0
# 15  2400     13.68    20.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib


df = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
plt.plot(df['武力值'], df['破釜沉舟战法倍率'], marker='o', label='pofuzhouchen')
plt.plot(df['武力值'], df['纣王战法倍率'], marker='s', label='zhouwang')
plt.title('Relationship Between Martial Power and Battle Multiplier')
plt.xlabel('wushu')
plt.ylabel('Battle Multiplier')
plt.grid(True)
plt.legend()
plt.show()
